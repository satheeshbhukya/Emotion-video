# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
import cv2 
import random 
import os  


from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.layers import Dense , Input ,Flatten , Conv2D , Dropout
from tensorflow.keras.layers import BatchNormalization,Activation,MaxPooling2D
from tensorflow.keras.models import Model , Sequential 
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.callbacks import ModelCheckpoint,ReduceLROnPlateau 
from tensorflow.keras.utils import plot_model  
    
from IPython.display import SVG, Image 
    
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.13.0'

# %% [markdown]
# Import Dataset

# %%
images = glob("train/**/**")
for i in range(9):
    image=random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# Training Dataset

# %%
img_size=48
batch_size=64
datagen_train= ImageDataGenerator()
train_generator=datagen_train.flow_from_directory("train/",
                                                    target_size=(img_size,img_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode="categorical",
                                                    shuffle=True)
datagen_validation=ImageDataGenerator() 
train_validation=datagen_train.flow_from_directory("test/",
                                                    target_size=(img_size,img_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode="categorical",
                                                    shuffle=True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# Model

# %%
def Convolution(input_tensor,filters,kernel_size):
        
        x = Conv2D(filters=filters,kernel_size=kernel_size,padding="same")(input_tensor)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = MaxPooling2D(pool_size=(2,2))(x)
        x = Dropout(0.25)(x) 
         
        return x 



def Dense_f(input_tensor,nodes):
        
        x = Dense(nodes)(input_tensor)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Dropout(0.25)(x) 
    
        return x 


def model_fer(input_shape):
        inputs = Input(input_shape)
        conv_1 = Convolution(inputs,32,(3,3)) 
        conv_2 = Convolution(inputs,64,(5,5))
        conv_3 = Convolution(inputs,128,(3,3)) 
    
        flatten = Flatten()(conv_3)
        dense_1 = Dense_f(flatten,256)
    
        output = Dense(7,activation="softmax")(dense_1)
    
        model=Model(inputs=[inputs],outputs=[output])
        model.compile(loss=['categorical_crossentropy'], optimizer='adam', metrics=['accuracy'])
    
        return model

# %%
model = model_fer((48,48,1))

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_5 (Conv2D)           (None, 48, 48, 128)       1280
#
#  batch_normalization_6 (Bat  (None, 48, 48, 128)       512
#  chNormalization)
#
#  activation_6 (Activation)   (None, 48, 48, 128)       0
#
#  max_pooling2d_5 (MaxPoolin  (None, 24, 24, 128)       0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten_1 (Flatten)         (None, 73728)             0
#
#  dense_2 (Dense)             (None, 256)               18874624
#
#  batch_normalization_7 (Bat  (None, 256)               1024
#  chNormalization)
#
#  activation_7 (Activation)   (None, 256)               0
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 18879239 (72.02 MB)
# Trainable params: 18878471 (72.02 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %% [markdown]
# Intialize Model

# %%
epochs = 15
steps_per_epoch= train_generator.n//train_generator.batch_size
validation_steps= train_validation.n//train_generator.batch_size

checkpoint=ModelCheckpoint("model_weights.h5",monitor='val_accuracy',save_weights_only=True,mode="max", verbose=1)
callbacks=[checkpoint]

# %% [markdown]
# Train Model

# %%
history=model.fit(
    x = train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=epochs,
    validation_data=train_validation,
    validation_steps=validation_steps,
    callbacks=callbacks)
# Out:
# Epoch 1/15
# 448/448 [==============================] - ETA: 0s - loss: 1.6445 - accuracy: 0.3784
# Epoch 1: saving model to model_weights.h5
# 448/448 [==============================] - 751s 2s/step - loss: 1.6445 - accuracy: 0.3784 - val_loss: 1.8428 - val_accuracy: 0.2628
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3519 - accuracy: 0.4883
# Epoch 2: saving model to model_weights.h5
# 448/448 [==============================] - 244s 545ms/step - loss: 1.3519 - accuracy: 0.4883 - val_loss: 1.6291 - val_accuracy: 0.3617
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1964 - accuracy: 0.5548
# Epoch 3: saving model to model_weights.h5
# 448/448 [==============================] - 245s 548ms/step - loss: 1.1964 - accuracy: 0.5548 - val_loss: 1.5193 - val_accuracy: 0.4056
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0637 - accuracy: 0.6075
# Epoch 4: saving model to model_weights.h5
# 448/448 [==============================] - 242s 541ms/step - loss: 1.0637 - accuracy: 0.6075 - val_loss: 1.4842 - val_accuracy: 0.4452
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9364 - accuracy: 0.6565
# Epoch 5: saving model to model_weights.h5
# 448/448 [==============================] - 723s 2s/step - loss: 0.9364 - accuracy: 0.6565 - val_loss: 1.4382 - val_accuracy: 0.4842
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8126 - accuracy: 0.7055
# Epoch 6: saving model to model_weights.h5
# 448/448 [==============================] - 7276s 16s/step - loss: 0.8126 - accuracy: 0.7055 - val_loss: 1.4609 - val_accuracy: 0.4768
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 0.7037 - accuracy: 0.7524
# Epoch 7: saving model to model_weights.h5
# 448/448 [==============================] - 453s 1s/step - loss: 0.7037 - accuracy: 0.7524 - val_loss: 1.8376 - val_accuracy: 0.3862
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5981 - accuracy: 0.7910
# Epoch 8: saving model to model_weights.h5
# 448/448 [==============================] - 305s 681ms/step - loss: 0.5981 - accuracy: 0.7910 - val_loss: 1.5470 - val_accuracy: 0.4862
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5117 - accuracy: 0.8222
# Epoch 9: saving model to model_weights.h5
# 448/448 [==============================] - 196s 436ms/step - loss: 0.5117 - accuracy: 0.8222 - val_loss: 1.7205 - val_accuracy: 0.4844
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.4364 - accuracy: 0.8516
# Epoch 10: saving model to model_weights.h5
# 448/448 [==============================] - 215s 480ms/step - loss: 0.4364 - accuracy: 0.8516 - val_loss: 1.8838 - val_accuracy: 0.4503
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3818 - accuracy: 0.8711
# Epoch 11: saving model to model_weights.h5
# 448/448 [==============================] - 214s 477ms/step - loss: 0.3818 - accuracy: 0.8711 - val_loss: 1.6685 - val_accuracy: 0.4842
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3337 - accuracy: 0.8882
# Epoch 12: saving model to model_weights.h5
# 448/448 [==============================] - 215s 479ms/step - loss: 0.3337 - accuracy: 0.8882 - val_loss: 2.1444 - val_accuracy: 0.4128
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3033 - accuracy: 0.8995
# Epoch 13: saving model to model_weights.h5
# 448/448 [==============================] - 228s 510ms/step - loss: 0.3033 - accuracy: 0.8995 - val_loss: 1.9400 - val_accuracy: 0.4616
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2644 - accuracy: 0.9122
# Epoch 14: saving model to model_weights.h5
# 448/448 [==============================] - 829s 2s/step - loss: 0.2644 - accuracy: 0.9122 - val_loss: 1.9086 - val_accuracy: 0.5081
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2496 - accuracy: 0.9171
# Epoch 15: saving model to model_weights.h5
# 448/448 [==============================] - 349s 779ms/step - loss: 0.2496 - accuracy: 0.9171 - val_loss: 1.9224 - val_accuracy: 0.5010

# %% [markdown]
# Model Evaluation

# %%
model.evaluate(train_validation)
# Out:
# 113/113 [==============================] - 11s 92ms/step - loss: 1.9232 - accuracy: 0.5011
# [1.9232350587844849, 0.5011144876480103]

# %% [markdown]
# Model Loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss']) 
plt.title('model loss')
plt.legend(['Train','Validation'],loc='upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0,hspace=0.25,wspace=0.35)

# %% [markdown]
# Model Accuracy

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_loss']) 
plt.title('model accuracy')
plt.legend(['Train','Validation'],loc='upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0,hspace=0.25,wspace=0.35)

# %% [markdown]
# Save Model

# %%
model_json=model.to_json()
with open("model_a.json","w") as json_file:
        json_file.write(model_json)
